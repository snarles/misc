# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import nibabel as nib

# %%
ls
# Out:
# */  FDR.ipynb  FDR.slides.html  fmri0.ipynb  images/

# %%
cd /home/snarles/hcp/10s/115320/MNINonLinear/Results/tfMRI_GAMBLING_LR/
# Out:
# /home/snarles/hcp/10s/115320/MNINonLinear/Results/tfMRI_GAMBLING_LR

# %%
ls
# Out:
# brainmask_fs.2.nii.gz          Movement_RelativeRMS.txt
# EVs/                           RibbonVolumeToSurfaceMapping/
# GAMBLING_run2_TAB.txt          tfMRI_GAMBLING_LR_Atlas.dtseries.nii
# Movement_AbsoluteRMS_mean.txt  tfMRI_GAMBLING_LR_hp200_s4_level1.fsf
# Movement_AbsoluteRMS.txt       tfMRI_GAMBLING_LR_Jacobian.nii.gz
# Movement_Regressors_dt.txt     tfMRI_GAMBLING_LR.nii.gz
# Movement_Regressors.txt        tfMRI_GAMBLING_LR_Physio_log.txt
# Movement_RelativeRMS_mean.txt  tfMRI_GAMBLING_LR_SBRef.nii.gz

# %%
mask = nib.load('brainmask_fs.2.nii.gz')

# %%
mask

# %%
data = mask.get_data()

# %%
np.shape(data)
# Out:
# (91, 109, 91)

# %%
plt.imshow(data[:, :, 70], cmap='bone')

# %%
tfm = nib.load('tfMRI_GAMBLING_LR.nii.gz')

# %%
print(tfm.get_header())
# Out:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       :
# db_name         :
# extents         : 0
# session_error   : 0
# regular         : r
# dim_info        : 0
# dim             : [  4  91 109  91 253   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.          2.          2.          2.          0.72000003  0.          0.
#   0.        ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : FSL5.0
# aux_file        :
# qform_code      : mni
# sform_code      : mni
# quatern_b       : 0.0
# quatern_c       : 1.0
# quatern_d       : 0.0
# ...

# %%
253 * .72
# Out:
# 182.16

# %%
tfm_data = tfm.get_data()

# %%
del tfm_data

# %%
plt.plot(tfm_data[50, 50, 50, :])

# %%
plt.figure(figsize = (16,3))
plt.imshow(np.hstack([tfm_data[:, :, 70, t] for t in np.arange(0,250,50)]))

# %%
cd /home/snarles/hcp/10s/115320/T1w/Diffusion/
# Out:
# /home/snarles/hcp/10s/115320/T1w/Diffusion

# %%
ls
# Out:
# bvals  bvecs  data.nii.gz  grad_dev.nii.gz  nodif_brain_mask.nii.gz

# %%
mask2 = nib.load('nodif_brain_mask.nii.gz')

# %%
m2data = mask2.get_data()

# %%
np.shape(m2data)
# Out:
# (145, 174, 145)

# %%
plt.imshow(m2data[:,:, 29])

# %%
.2 * 145
# Out:
# 29.0

# %%
.2*91
# Out:
# 18.2

# %%
cd /home/snarles/hcp/10s/103414/MNINonLinear/Results/tfMRI_GAMBLING_LR/
# Out:
# /home/snarles/hcp/10s/103414/MNINonLinear/Results/tfMRI_GAMBLING_LR

# %%
tfm = nib.load('tfMRI_GAMBLING_LR.nii.gz')

# %%
print(tfm.get_header())
# Out:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       :
# db_name         :
# extents         : 0
# session_error   : 0
# regular         : r
# dim_info        : 0
# dim             : [  4  91 109  91 253   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.          2.          2.          2.          0.72000003  0.          0.
#   0.        ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : FSL5.0
# aux_file        :
# qform_code      : mni
# sform_code      : mni
# quatern_b       : 0.0
# quatern_c       : 1.0
# quatern_d       : 0.0
# ...
